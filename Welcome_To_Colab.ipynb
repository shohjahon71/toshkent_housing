# %% [markdown]
# <a href="https://colab.research.google.com/github/shohjahon71/toshkent_housing/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Toshkent shahrida uylarning narxini aniqlash

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#   size  level  max_levels  price
# 0   57      4           4  52000
# 1   52      4           5  56000
# 2   42      4           4  37000
# 3   65      1           4  49500
# 4   70      3           5  55000

# %% [markdown]
# # Ma'lumotlarni o'rganamiz, analiz qilib va kerakli o'zgartrishlarni bajaramiz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7565 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7565 non-null   object
#  1   district    7565 non-null   object
#  2   rooms       7565 non-null   int64
#  3   size        7565 non-null   object
#  4   level       7565 non-null   int64
#  5   max_levels  7565 non-null   int64
#  6   price       7565 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 413.8+ KB

# %% [markdown]
# Yuqoridagi m'lumotlardan 'size' (o'lcham) va 'price' (narx) ustunlari object ekanligini ko'rishimiz mumkin. Bu ustunlarni sonli ustunlarga o'zgartrish kerak.

# %%
df_n = df
df_f = df_n.drop(['location', 'district'], axis=1)
for col in list(df_f.columns):
       if type(col) != int:
            df_n[col] = pd.to_numeric(df_f[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7565 entries, 0 to 7564
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    7565 non-null   object
#  1   district    7565 non-null   object
#  2   rooms       7565 non-null   int64
#  3   size        7564 non-null   float64
#  4   level       7565 non-null   int64
#  5   max_levels  7565 non-null   int64
#  6   price       7466 non-null   float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 413.8+ KB

# %% [markdown]
# # O'zgartrilgan ma'lumotlarimizni tekshiramiz.

# %%
df_n.isna().sum()
# Out:
# location       0
# district       0
# rooms          0
# size           1
# level          0
# max_levels     0
# price         99
# dtype: int64

# %% [markdown]
# 'size' ustunida bir dona va 'price' ustunida 99 ta NaN qiymatlar mavjud ekanini ko'ramiz. Barcha ustunlardagi NaN qiymatlarni tashlab yuboramiz.

# %%
df_n = df_n.dropna()
df_n.isna().sum()
# Out:
# location      0
# district      0
# rooms         0
# size          0
# level         0
# max_levels    0
# price         0
# dtype: int64

# %% [markdown]
# NaN qiymatlar ustida ishladik. Endi ma'lumotlarni o'rganib chiqamiz.

# %%
print(f"max_size : {df_n['size'].max()}   min_size : {df_n['size'].min()}")
# Out:
# max_size : 70000.0   min_size : 1.0

# %% [markdown]
# Uylarning o'lchamlari normal oraliqda emas minimal o'cham 1 kv.metr desak max o'lcham 70000 kv.metr, bu judaham katta. Demak ma'lumotlarimizni filtrlashimiz kerak.

# %%
df_n[df_n['size']<15][df_n['rooms']>1]
# Out:
# /tmp/ipykernel_5774/2713091541.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# 1934      5    280.0      6           8  320000.0
# 1945      5    254.0      1           8  285000.0
# 1946      6    252.0      1           8  285000.0
# 1968      6    252.0      1           8  285000.0
# 1990      5    254.0      1           8  285000.0
# 1999      5    300.0      3           8  425000.0
# 2268      1  24500.0      2           5   24500.0
# 2290      4    279.0      1           3  150000.0
# 2382      6    347.0      3           9  240000.0
# 2383      5    280.0      1           8  280000.0
# 2547      3  70000.0      2           4   76000.0
# 2662      1   3448.0      5           5   25000.0
# 2965      7    360.0      5           6  300000.0
# 3089      2  44000.0      3           4   44000.0
# 3280      6    270.0      2           4  270000.0
# 3656      5    336.0      8           9  504000.0
# 3779      4    282.0      7           8  305000.0
# 3977      3    313.0      5           5   65000.0
# 3979      6    260.0      1           4  259000.0
# 4089      6    500.0      2           2    1800.0
# 4411      5    321.0      1           1   48000.0
# 4615      4  69000.0      3           4   69000.0
# 4622      3    290.0      1           5  270000.0
# 4784      3   7359.0      2           4   46500.0
# 5111      7    320.0      7           7  130000.0
# 5118     10    456.0      3           7  800000.0
# 5197      6    420.0      7           7  200000.0
# 5349      6    252.0      1           8  285000.0
# 5456      3  67000.0      2           5   67000.0
# 5461      5    254.0      1           8  285000.0
# 5708      6    268.0      1           3  260000.0
# 5757      3    260.0      1           6  235000.0
# 5874     10    448.0      7           7  425600.0
# 5974      4    320.0      4           4  255000.0
# 5976      4    320.0      4           4  255000.0
# 6545      7    320.0      7           7  130000.0
# 6702      2    280.0      9           9   48000.0
# 6851      6    341.0      2           3  250000.0
# 7043      4   7407.0      4           4   44000.0
# 7421      8   2100.0      1           1  265000.0

# %% [markdown]
# Oddatda 1 xonali uylarnig minimal o'lchami 10 kv.metr atrofida bo'ladi. Lekin bizga berilgan ma'lumotlarda 10 kv.m dan kichik va xonalari 2 va undan ortiq bo'lgan uylar mavjud. Bu ma'lumotlar bizning modelimizni noto'g'ri bashorat qilishiga tasir qilishi mumkin, shuning uchun bu ma'lumotlarni tashlab yuboramiz.

# %%
df_n = df_n.drop(df_n[df_n['size']<15][df_n['rooms']>1].index)
df_n = df_n.drop(df_n[df_n['size']>250].index)
df_n = df_n.drop(df_n[df_n['size']==2100].index)
# Out:
# /tmp/ipykernel_5774/4149483698.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_n = df_n.drop(df_n[df_n['size']<15][df_n['rooms']>1].index)

# %%
print(f"max_price : {df_n['price'].max()}   min_price : {df_n['price'].min()}")
# Out:
# max_price : 52000000.0   min_price : 2.0

# %% [markdown]
# Uylarning narxlaridaham ushbu nomutanosiblikni kuzatishimiz mumkin minimal narx 2 USD desak max narx 52000000 USD , buham juda katta. Ma'lumotlarimizni yana filtrlashimiz kerak.

# %%
df_n[df_n['price']<7000][df_n['rooms']>1]
# Out:
# /tmp/ipykernel_5774/2319351010.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_n[df_n['price']<7000][df_n['rooms']>1]
#                                                location         district  \
# 273           город Ташкент, Яккасарайский район, Нукус    Яккасарайский
# 3832  город Ташкент, Яккасарайский район, Абдуллы Ка...    Яккасарайский
# 5073  город Ташкент, Сергелийский район, Srrgili 8uc...     Сергелийский
# 5719      город Ташкент, Шайхантахурский район, Караташ  Шайхантахурский
# 7224      город Ташкент, Учтепинский район, Чиланзар-11      Учтепинский
#
#       rooms   size  level  max_levels   price
# 273       3  100.0      3           4  1000.0
# 3832      4  170.0      2           6  2000.0
# 5073      2   54.0      7           7  2864.0
# 5719      7  230.0      2           5  1000.0
# 7224      2   51.0      2           4     2.0

# %%
df_n[df_n['price']>200000]
# Out:
#                                                location           district  \
# 189   город Ташкент, Мирзо-Улугбекский район, Буюк И...  Мирзо-Улугбекский
# 310   город Ташкент, Яккасарайский район, Кичик Бешагач      Яккасарайский
# 330   город Ташкент, Яшнободский район, 1-й переулок...        Яшнободский
# 345           город Ташкент, Мирабадский район, Окбилол        Мирабадский
# 346         город Ташкент, Мирабадский район, Янгизамон        Мирабадский
# ...                                                 ...                ...
# 6952  город Ташкент, Шайхантахурский район, Алишера ...    Шайхантахурский
# 7081      город Ташкент, Чиланзарский район, Тирсакобод       Чиланзарский
# 7296  город Ташкент, Яшнободский район, Садыка Азимо...        Яшнободский
# 7466  город Ташкент, Чиланзарский район, 1-й проезд ...       Чиланзарский
# 7478  город Ташкент, Чиланзарский район, Катта козир...       Чиланзарский
#
#       rooms   size  level  max_levels       price
# 189       4  187.0      2           5    210000.0
# 310       4  210.0      4           8    265000.0
# 330       2   68.0      5           8   1666000.0
# 345       4  165.0      1           8    264999.0
# 346       4  215.0      5           8    259999.0
# ...     ...    ...    ...         ...         ...
# 6952      3  114.0      5           7  15504000.0
# 7081      2   85.0      2           3   6630000.0
# 7296      4   96.0      2           5   5568000.0
# 7466      2   42.0      1           3   1470000.0
# 7478      1   28.0      3           4    644000.0
#
# [126 rows x 7 columns]

# %% [markdown]
# Demak xonalar soni 2 va undan ortiq lekin narxlari juda past va xonalar soni kam lekin narxi juda yuqori bo'lgan real narxga to'g'ri kelmaydigan uylarni ko'rishimiz mumkin. Bu uylarni ham tashlab yuboramiz.

# %%
df_n = df_n.drop(df_n[df_n['price']<7000][df_n['rooms']>1].index)
df_n = df_n.drop(df_n[df_n['price']>200000].index)
# Out:
# /tmp/ipykernel_5774/63190184.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_n = df_n.drop(df_n[df_n['price']<7000][df_n['rooms']>1].index)

# %% [markdown]
# # Filtrlangan ma'lumotlarimizni endi Grafik usulda taxlil qilamiz

# %%
df_n = df_n.reset_index(drop=True)

df_1 = df_n.drop(['location', 'district'], axis=1)

# %%
# %matplotlib inline
df_1.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# #UYLARNING NARXI BO'YICHA

# %%
# %matplotlib inline
df_p=df_n[['price']]
df_p['price'].hist(bins=50, figsize=(9,6))
plt.show()

# %%
df_pf=df_n[df_n['price']<250000]
plt.figure(figsize=(12,6))
sns.histplot(data=df_pf, x='price')
plt.grid(which='both')
plt.minorticks_on()
plt.show()

# %% [markdown]
# Bu grafikdan 80 % ga yaqin uylarning narxi 20000 - 100000 USD oralig'ida ekanligini ko'rishimiz mumkin.

# %% [markdown]
# # UYLARNING MAYDONI BO'YICHA

# %%
# %matplotlib inline
df_s=df_n[['size']]
df_s['size'].hist(bins=50, figsize=(9,6))
plt.show()

# %%
df_sf=df_n[df_n['size']<150]
plt.figure(figsize=(12,6))
sns.histplot(data=df_sf, x='size')
plt.grid(which='both')
plt.minorticks_on()
plt.show()

# %% [markdown]
# Bu grafikdan aksar uylarning maydoni 25 - 100 kv.metr oralig'ida ekanligini ko'rishimiz mumkin.

# %% [markdown]
# # UYLARNING XONALAR SONI BO'YICHA

# %%
# %matplotlib inline
df_r=df_n[['rooms']]
df_r['rooms'].hist(bins=20, figsize=(9,6))
plt.show()

# %% [markdown]
# Uylarning katta qismi 2 xonlidan 4 xonaligacha ekanini ko'rishimiz mumkin.

# %% [markdown]
# # UY NARXIGA ENG KO'P TASIR QILADIGAN PARAMETRLARNI KO'RIB CHIQAMIZ

# %%
df_1.corrwith(df_1['price']).sort_values(ascending=False)
# Out:
# price         1.000000
# size          0.787158
# rooms         0.603204
# max_levels    0.268437
# level         0.085466
# dtype: float64

# %% [markdown]
# Bu ro'yxatimizda uylarning maydoni va xonalar soni uy narxini asosiy belgilab beruvchi parametrlar ekanini ko'ramiz.

# %% [markdown]
# # Bu parametrlarni grafik ko'rinishi

# %%
cols = ['price','size','rooms','max_levels']
sns.pairplot(df_1[cols], height=3)
plt.show()

# %% [markdown]
# Grafiklardan ham ko'rinib turibdi. Uy maydonlarining ortishi natijasida uy narxlarining ko'tarilishi kuzatilayabdi. Bu natijani xonalar soni ortishi bilan ham kuzatish mumkin.

# %% [markdown]
# # Uy narxiga eng katta ta'sir qiluvchi omil bu uy maydonlari ekan. Ushbu grafigimizda bu narsa judaham yaxshi ko'rinib turibdi.

# %%
df_n.plot(kind='scatter', x="size", y="price", alpha=0.1, figsize=(9,7))
plt.show()

# %% [markdown]
# #Ma`lumotlarni ML uchun tayyolrash

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/housing_data_08-02-2021.csv')
df.head()
# Out:
#                                             location       district  rooms  \
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...   Юнусабадский      3
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  Яккасарайский      2
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...   Чиланзарский      2
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...   Чиланзарский      3
# 4  город Ташкент, Чиланзарский район, площадь Актепа   Чиланзарский      3
#
#   size  level  max_levels  price
# 0   57      4           4  52000
# 1   52      4           5  56000
# 2   42      4           4  37000
# 3   65      1           4  49500
# 4   70      3           5  55000

# %%
from sklearn.base import BaseEstimator, TransformerMixin
size_ix, price_ix = 3, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        df_n = X.copy()
        df_f = df_n.drop(['location', 'district'], axis=1)
        for col in df_f.columns:
            if df_f[col].dtype == 'object':
                df_n[col] = pd.to_numeric(df_f[col], errors='coerce')
        df_n = df_n.dropna()
        df_n = df_n.drop(df_n[df_n['size']<15][df_n['rooms']>1].index)
        df_n = df_n.drop(df_n[df_n['size']>250].index)
        df_n = df_n.drop(df_n[df_n['size']==2100].index)
        df_n = df_n.drop(df_n[df_n['price']<7000][df_n['rooms']>1].index)
        df_n = df_n.drop(df_n[df_n['price']>200000].index)
        return df_n

combined_adder = CombinedAttributesAdder()

transformed_data = combined_adder.transform(df)

df_n = transformed_data
# Out:
# /tmp/ipykernel_5774/116473704.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_n = df_n.drop(df_n[df_n['size']<15][df_n['rooms']>1].index)
# /tmp/ipykernel_5774/116473704.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_n = df_n.drop(df_n[df_n['price']<7000][df_n['rooms']>1].index)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df_n, test_size=0.2, random_state=42)

X_train = train_set.drop("price", axis=1)
y = train_set["price"].copy()

X_num = X_train.drop(["district",'location'], axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

num_pipeline = Pipeline([
          ('std_scaler', StandardScaler())
])

# %%
from sklearn.compose import ColumnTransformer

num_attribs = list(X_num)
cat_attribs = ['district']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', OrdinalEncoder(), cat_attribs)
])

# %%
X_prepared = full_pipeline.fit_transform(X_train)
X_prepared[0:5,:]
# Out:
# array([[ 1.38904861e+00,  2.26157807e+00,  5.88274615e-01,
#         -3.01186764e-03,  9.00000000e+00],
#        [-5.51946480e-01, -3.42901073e-01,  1.92633657e+00,
#          1.13881335e+00,  2.00000000e+00],
#        [-5.51946480e-01, -6.90164959e-01,  1.42253963e-01,
#         -7.64228676e-01,  1.10000000e+01],
#        [-5.51946480e-01, -1.69269130e-01, -1.19580799e+00,
#          1.13881335e+00,  2.00000000e+00],
#        [ 1.38904861e+00,  9.07248915e-01,  1.92633657e+00,
#          1.13881335e+00,  4.00000000e+00]])

# %% [markdown]
# # Machine Learning

# %% [markdown]
# LinearRegression

# %%
from sklearn.linear_model import LinearRegression

LR_model = LinearRegression()

# %%
LR_model.fit(X_prepared, y)
# Out:
# LinearRegression()

# %%
# tasodifiy 5 ta qatorni ajratib olamiz
test_data = X_train.sample(5)
test_data
# Out:
#                                                location      district  rooms  \
# 6261           город Ташкент, Чиланзарский район, Лутфи  Чиланзарский      2
# 2747  город Ташкент, Учтепинский район, Чиланзар 13-...   Учтепинский      4
# 4640    город Ташкент, Олмазорский район, Каракамыш-1/4   Олмазорский      2
# 4705          город Ташкент, Мирабадский район, Фаровон   Мирабадский      3
# 4682  город Ташкент, Олмазорский район, Бируни-3 Олм...   Олмазорский      2
#
#       size  level  max_levels
# 6261  63.0      2           5
# 2747  90.0      5           5
# 4640  60.0      4           5
# 4705  75.0      8           9
# 4682  56.0      2           5

# %%
# yuqoridagi qatorlarga mos keluvchi narxlarni ajratib olamiz (biz aynan shu qiymatlarni bashorat qilishimiz kerak)
test_label = y.loc[test_data.index]
test_label
# Out:
# 6261    46500.0
# 2747    42500.0
# 4640    33000.0
# 4705    65000.0
# 4682    38000.0
# Name: price, dtype: float64

# %%
test_data_prepared = full_pipeline.transform(test_data)
test_data_prepared
# Out:
# array([[-0.55194648, -0.23872191, -0.74978734, -0.38362027,  6.        ],
#        [ 1.38904861,  0.69889058,  0.58827461, -0.38362027,  5.        ],
#        [-0.55194648, -0.34290107,  0.14225396, -0.38362027,  3.        ],
#        [ 0.41855107,  0.17799476,  1.92633657,  1.13881335,  1.        ],
#        [-0.55194648, -0.48180663, -0.74978734, -0.38362027,  3.        ]])

# %%
predicted_data = LR_model.predict(test_data_prepared)
predicted_data
# Out:
# array([51231.94490688, 64503.01306794, 46766.57868666, 55516.33379843,
#        46353.35097039])

# %%
pd.DataFrame({'Prognoz':predicted_data, 'Real baxosi': test_label})
# Out:
#            Prognoz  Real baxosi
# 6261  51231.944907      46500.0
# 2747  64503.013068      42500.0
# 4640  46766.578687      33000.0
# 4705  55516.333798      65000.0
# 4682  46353.350970      38000.0

# %%
test_set
# Out:
#                                                location           district  \
# 1453  город Ташкент, Чиланзарский район, Чиланзар 8-...       Чиланзарский
# 4817       город Ташкент, Мирзо-Улугбекский район, ОВИР  Мирзо-Улугбекский
# 2973  город Ташкент, Чиланзарский район, Чиланзар 5-...       Чиланзарский
# 4252    город Ташкент, Мирзо-Улугбекский район, Паркент  Мирзо-Улугбекский
# 4134        город Ташкент, Чиланзарский район, Чиланзар       Чиланзарский
# ...                                                 ...                ...
# 3598  город Ташкент, Учтепинский район, Чиланзар 22-...        Учтепинский
# 294   город Ташкент, Чиланзарский район, Чиланзар 6-...       Чиланзарский
# 2115  город Ташкент, Юнусабадский район, Ислама Кари...       Юнусабадский
# 2392  город Ташкент, Олмазорский район, Каракамыш кв...        Олмазорский
# 2540  город Ташкент, Мирзо-Улугбекский район, Буюк И...  Мирзо-Улугбекский
#
#       rooms   size  level  max_levels     price
# 1453      1   40.0      1           4   28500.0
# 4817      1   30.0      2           4   30000.0
# 2973      2   52.0      1           4   41000.0
# 4252      3  115.0      2           9  115000.0
# 4134      1   42.0      4           9   28500.0
# ...     ...    ...    ...         ...       ...
# 3598      3   68.0      2           4   40000.0
# 294       2   44.0      1           4   38000.0
# 2115      3  125.0      5           9  110000.0
# 2392      1   42.0      4           5   22800.0
# 2540      3   84.0      3           4  107000.0
#
# [1454 rows x 7 columns]

# %%
X_test = test_set.drop('price', axis=1)
X_test
# Out:
#                                                location           district  \
# 1453  город Ташкент, Чиланзарский район, Чиланзар 8-...       Чиланзарский
# 4817       город Ташкент, Мирзо-Улугбекский район, ОВИР  Мирзо-Улугбекский
# 2973  город Ташкент, Чиланзарский район, Чиланзар 5-...       Чиланзарский
# 4252    город Ташкент, Мирзо-Улугбекский район, Паркент  Мирзо-Улугбекский
# 4134        город Ташкент, Чиланзарский район, Чиланзар       Чиланзарский
# ...                                                 ...                ...
# 3598  город Ташкент, Учтепинский район, Чиланзар 22-...        Учтепинский
# 294   город Ташкент, Чиланзарский район, Чиланзар 6-...       Чиланзарский
# 2115  город Ташкент, Юнусабадский район, Ислама Кари...       Юнусабадский
# 2392  город Ташкент, Олмазорский район, Каракамыш кв...        Олмазорский
# 2540  город Ташкент, Мирзо-Улугбекский район, Буюк И...  Мирзо-Улугбекский
#
#       rooms   size  level  max_levels
# 1453      1   40.0      1           4
# 4817      1   30.0      2           4
# 2973      2   52.0      1           4
# 4252      3  115.0      2           9
# 4134      1   42.0      4           9
# ...     ...    ...    ...         ...
# 3598      3   68.0      2           4
# 294       2   44.0      1           4
# 2115      3  125.0      5           9
# 2392      1   42.0      4           5
# 2540      3   84.0      3           4
#
# [1454 rows x 6 columns]

# %%
y_test = test_set['price'].copy()
y_test
# Out:
# 1453     28500.0
# 4817     30000.0
# 2973     41000.0
# 4252    115000.0
# 4134     28500.0
#           ...
# 3598     40000.0
# 294      38000.0
# 2115    110000.0
# 2392     22800.0
# 2540    107000.0
# Name: price, Length: 1454, dtype: float64

# %%
X_test_prepared = full_pipeline.transform(X_test)

# %%
y_predicted = LR_model.predict(X_test_prepared)

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 17941.86731818831

# %%
from sklearn.tree import DecisionTreeRegressor
Tree_model = DecisionTreeRegressor()
Tree_model.fit(X_prepared, y)
# Out:
# DecisionTreeRegressor()

# %%
y_predicted = Tree_model.predict(X_test_prepared)

# %%
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 17744.91535251343

# %%
from sklearn.ensemble import RandomForestRegressor
RF_model = RandomForestRegressor()
RF_model.fit(X_prepared, y)
# Out:
# RandomForestRegressor()

# %%
y_predicted = RF_model.predict(X_test_prepared)
lin_mse = mean_squared_error(y_test, y_predicted)
# RMSE hisoblaymiz
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)
# Out:
# 14157.452806235651

# %%
X = df_n.drop("price", axis=1)
y = df_n["price"].copy()

X_prepared = full_pipeline.transform(X)

# %%
X = df_n.drop("price", axis=1)
y = df_n["price"].copy()

X_prepared = full_pipeline.transform(X)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Std.dev:", scores.std())

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(LR_model, X_prepared, y, scoring="neg_mean_squared_error", cv=10)
LR_rmse_scores = np.sqrt(-scores)

# %%
display_scores(LR_rmse_scores)
# Out:
# Scores: [15503.57062689 16322.65299131 19568.70800942 19487.73430478
#  19613.89627834 19904.17506981 16581.96463684 15840.15278261
#  18323.50189642 16111.99997825]
# Mean: 17725.835657468433
# Std.dev: 1718.8279629518222

# %%
scores = cross_val_score(Tree_model, X_prepared, y, scoring="neg_mean_squared_error", cv=10)
LR_rmse_scores = np.sqrt(-scores)
display_scores(LR_rmse_scores)
# Out:
# Scores: [15357.60628175 15621.9924815  21151.58551079 20034.36451533
#  20567.96757841 18729.90963004 18338.4808429  16932.6767848
#  18715.47545423 16556.53722032]
# Mean: 18200.65963000742
# Std.dev: 1930.8577177660577

# %%
scores = cross_val_score(RF_model, X_prepared, y, scoring="neg_mean_squared_error", cv=10)
LR_rmse_scores = np.sqrt(-scores)
display_scores(LR_rmse_scores)
# Out:
# Scores: [12269.20546516 13310.01715723 16660.7722346  17074.07175105
#  16696.0369153  15291.32921946 13710.62538626 13240.01048069
#  14190.00374995 13471.67748877]
# Mean: 14591.374984846796
# Std.dev: 1625.3246559464883
